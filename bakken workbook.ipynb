# %%
import pandas as pd

# %%
df = pd.ExcelFile(r"C:\Users\ktjone1\Downloads\Bakken2018 Excel Well Workbook_2.xlsx")

# %%
import os

# %%
h = df.parse(0)

# %%
h = h.merge(t, left_on="UWI", right_on="UWI", how="outer")

# %%
t = df.parse("Formation")

# %%
h.describe()
# Out:
#                 UWI    API Number     IC Number  Regulatory API  OS Indicator  \
# count  7.612000e+04  7.612000e+04  1.700000e+01    7.058300e+04           0.0
# mean   3.305174e+13  3.305174e+13  3.305376e+13    3.305172e+09           NaN
# std    5.839296e+09  5.839296e+09  0.000000e+00    5.943447e+05           NaN
# min    3.302503e+13  3.302503e+13  3.305376e+13    3.302502e+09           NaN
# 25%    3.305304e+13  3.305304e+13  3.305376e+13    3.305304e+09           NaN
# 50%    3.305305e+13  3.305305e+13  3.305376e+13    3.305305e+09           NaN
# 75%    3.305306e+13  3.305306e+13  3.305376e+13    3.305306e+09           NaN
# max    3.305308e+13  3.305308e+13  3.305376e+13    3.306101e+09           NaN
#
#        Basin Code  Sub Basin Code  Permit Number  Depth Total Driller  \
# count     76120.0    7.612000e+04   76115.000000         76120.000000
# mean     713200.0    1.000000e+11   25894.319070         20278.823450
# std           0.0    1.062507e+00    4999.760499          2101.757227
# min      713200.0    1.000000e+11    3118.000000          9050.000000
# 25%      713200.0    1.000000e+11   22610.000000         20421.000000
# 50%      713200.0    1.000000e+11   26533.000000         20839.000000
# 75%      713200.0    1.000000e+11   29934.500000         21190.000000
# max      713200.0    1.000000e+11   33129.000000         27242.000000
#
#        Depth Total Logger     ...      Gel/x-link (Gals)  \
# count         1235.000000     ...           7.390600e+04
# mean         16325.964372     ...           3.235894e+06
# std           5046.556010     ...           3.225679e+06
# min           9057.000000     ...           0.000000e+00
# 25%          10812.000000     ...           3.820850e+05
# 50%          19819.000000     ...           2.641128e+06
# 75%          20738.000000     ...           4.307856e+06
# max          25213.000000     ...           2.407301e+07
#
#        Fluid - Explosive (Gals)  Fluid - Other (Gals)  Total Fluid (gals)  \
# count                   73906.0          7.390600e+04        7.390600e+04
# mean                        0.0          3.164891e+05        4.245349e+06
# std                         0.0          1.311679e+06        3.278156e+06
# min                         0.0          0.000000e+00        0.000000e+00
# 25%                         0.0          0.000000e+00        2.197776e+06
# 50%                         0.0          0.000000e+00        3.249918e+06
# 75%                         0.0          0.000000e+00        5.229116e+06
# max                         0.0          1.289030e+07        2.409150e+07
#
#        Total Proppant (lbs.) / Total Fluid (gal)  Interpreter     Depth Top  \
# count                               73906.000000          0.0  63564.000000
# mean                                    1.215427          NaN   9289.748741
# std                                     1.231149          NaN   1952.685657
# min                                     0.000000          NaN    685.000000
# 25%                                     0.943385          NaN   8296.000000
# 50%                                     1.187936          NaN   9719.000000
# 75%                                     1.486501          NaN  10918.000000
# max                                   101.178459          NaN  20433.000000
#
#          Base Depth  Reason  Fault Type
# count   6194.000000     0.0         0.0
# mean    9031.053923     NaN         NaN
# std      780.169111     NaN         NaN
# min     1504.000000     NaN         NaN
# 25%     8946.000000     NaN         NaN
# 50%     9222.000000     NaN         NaN
# 75%     9466.000000     NaN         NaN
# max    11278.000000     NaN         NaN
#
# [8 rows x 64 columns]

# %%
list(h)
# Out:
# ['UWI',
#  'Source_x',
#  'API Number',
#  'IC Number',
#  'Regulatory API',
#  'Operator Name',
#  'Current Operator Name',
#  'Lease Name',
#  'Well Num',
#  'Field Name',
#  'Country Name',
#  'State Name',
#  'County Name',
#  'OS Indicator',
#  'Hole Direction',
#  'Final Status',
#  'Current Status',
#  'Basin',
#  'Basin Code',
#  'Sub Basin',
#  'Sub Basin Code',
#  'Play Name',
#  'Play Type',
#  'Permit Number',
#  'Permit Date',
#  'Depth Total Driller',
#  'Depth Total Logger',
#  'Depth True Vertical',
#  'Depth Whipstock',
#  'Class Initial Name',
#  'Class Initial Code',
#  'Class Final Name',
#  'Class Final Code',
#  'Status Final Code',
#  'Formation Projected Name',
#  'Depth Total Projected',
#  'Formation at TD Name',
#  'PRODFit Formation at TD Name',
#  'Formation Producing Name',
#  'PRODFit Top Formation Producing Name',
#  'PRODFit Base Formation Producing Name',
#  'Elevation Reference Value',
#  'Elevation Reference Datum',
#  'Ground Elevation',
#  'Date First Spud',
#  'Date Spud',
#  'Date Completion',
#  'Date Rig Release',
#  'Date Abandonment',
#  'Date First Report',
#  'Date Last Activity',
#  'Depth Water Value',
#  'Depth Water Datum',
#  'Surface Latitude',
#  'Surface Longitude',
#  'Surface LL Source',
#  'Proposed BH Latitude',
#  'Proposed BH Longitude',
#  'Proposed BH LL Source',
#  'BH Latitude',
#  'BH Longitude',
#  'BH LL Source',
#  'Activity Code',
#  'Permit Filer Long',
#  'Permit Phone',
#  'Source_y',
#  'Num Frac Stages',
#  'Stages Avail',
#  'Num Treatment Records',
#  'Proppant - Sand (lbs)',
#  'Proppant - Resin Coated Sand (lbs)',
#  'Proppant - Ceramic (lbs)',
#  'Proppant - Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Ceramic (lbs)',
#  'Proppant - Sand, Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Ceramic, Resin Coated Sand (lbs)',
#  'Proppant - Sand, Ceramic, Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Resin Coated Sand, Ceramic, Resin Coated Ceramic (lbs)',
#  'Proppant - Bauxite (lbs)',
#  'Proppant - Walnut (lbs)',
#  'Proppant - Marble (lbs)',
#  'Proppant - Gravel (lbs)',
#  'Proppant - Sand, Bauxite Ceramic (lbs)',
#  'Proppant - Other (lbs)',
#  'Total Proppant (lbs)',
#  'Fluid/Water (Gals)',
#  'Fluid - Slick Water (Gals)',
#  'Fluid - Salt Water (Gals)',
#  'Fluid - Foam (Gals)',
#  'Fluid - Oil (Gals)',
#  'Fluid - Potassium Chloride (Gals)',
#  'Fluid - Surfactant (Gals)',
#  'Fluid - Emulsion (Gals)',
#  'N2/CO2 Gas (Gals)',
#  'Acid (Gals)',
#  'Gel/x-link (Gals)',
#  'Fluid - Explosive (Gals)',
#  'Fluid - Other (Gals)',
#  'Total Fluid (gals)',
#  'Total Proppant (lbs.) / Total Fluid (gal)',
#  'Top Source',
#  'Interpreter',
#  'Code',
#  'Name',
#  'Depth Top',
#  'Depth Top UOM',
#  'Base Depth',
#  'Base Depth UOM',
#  'Source Name',
#  'Reason',
#  'Remark',
#  'Fault Type']

# %%
test1 = [
    "UWI",
    "Operator Name",
    "Current Operator Name",
    "Lease Name",
    "Well Num",
    "OS Indicator",
    "Hole Direction",
    "Final Status",
    "Current Status",
    "Basin",
    "Basin Code",
    "Sub Basin",
    "Sub Basin Code",
    "Play Name",
    "Play Type",
    "Permit Date",
    "Depth Total Driller",
    "Depth Total Logger",
    "Depth True Vertical",
    "Depth Whipstock",
    "Class Initial Name",
    "Class Initial Code",
    "Class Final Name",
    "Class Final Code",
    "Status Final Code",
    "Formation Projected Name",
    "Depth Total Projected",
    "Formation at TD Name",
    "PRODFit Formation at TD Name",
    "Formation Producing Name",
    "PRODFit Top Formation Producing Name",
    "PRODFit Base Formation Producing Name",
    "Elevation Reference Value",
    "Elevation Reference Datum",
    "Ground Elevation",
    "Date First Spud",
    "Date Spud",
    "Date Completion",
    "Date Rig Release",
    "Date First Report",
    "Date Last Activity",
    "Depth Water Value",
    "Depth Water Datum",
    "Surface Latitude",
    "Surface Longitude",
    "Surface LL Source",
    "BH Latitude",
    "BH Longitude",
    "BH LL Source",
    "Activity Code",
    "Source_y",
    "Num Frac Stages",
    "Stages Avail",
    "Num Treatment Records",
    "Proppant - Sand (lbs)",
    "Proppant - Resin Coated Sand (lbs)",
    "Proppant - Ceramic (lbs)",
    "Proppant - Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Ceramic (lbs)",
    "Proppant - Sand, Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Ceramic, Resin Coated Sand (lbs)",
    "Proppant - Sand, Ceramic, Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Resin Coated Sand, Ceramic, Resin Coated Ceramic (lbs)",
    "Proppant - Bauxite (lbs)",
    "Proppant - Walnut (lbs)",
    "Proppant - Marble (lbs)",
    "Proppant - Gravel (lbs)",
    "Proppant - Sand, Bauxite Ceramic (lbs)",
    "Proppant - Other (lbs)",
    "Total Proppant (lbs)",
    "Fluid/Water (Gals)",
    "Fluid - Slick Water (Gals)",
    "Fluid - Salt Water (Gals)",
    "Fluid - Foam (Gals)",
    "Fluid - Oil (Gals)",
    "Fluid - Potassium Chloride (Gals)",
    "Fluid - Surfactant (Gals)",
    "Fluid - Emulsion (Gals)",
    "N2/CO2 Gas (Gals)",
    "Acid (Gals)",
    "Gel/x-link (Gals)",
    "Fluid - Explosive (Gals)",
    "Fluid - Other (Gals)",
    "Total Fluid (gals)",
    "Total Proppant (lbs.) / Total Fluid (gal)",
    "Top Source",
    "Interpreter",
    "Code",
    "Name",
    "Depth Top",
    "Depth Top UOM",
    "Base Depth",
    "Base Depth UOM",
]

# %%
g = h[test1]

# %%
g.head()
# Out:
#               UWI                         Operator Name  \
# 0  33025028850000  ENERPLUS RESOURCES (USA) CORPORATION
# 1  33025028850000  ENERPLUS RESOURCES (USA) CORPORATION
# 2  33025028850000  ENERPLUS RESOURCES (USA) CORPORATION
# 3  33025028850000  ENERPLUS RESOURCES (USA) CORPORATION
# 4  33025028850000  ENERPLUS RESOURCES (USA) CORPORATION
#
#                   Current Operator Name Lease Name        Well Num  \
# 0  ENERPLUS RESOURCES (USA) CORPORATION       BARN  147-94-13A-24H
# 1  ENERPLUS RESOURCES (USA) CORPORATION       BARN  147-94-13A-24H
# 2  ENERPLUS RESOURCES (USA) CORPORATION       BARN  147-94-13A-24H
# 3  ENERPLUS RESOURCES (USA) CORPORATION       BARN  147-94-13A-24H
# 4  ENERPLUS RESOURCES (USA) CORPORATION       BARN  147-94-13A-24H
#
#    OS Indicator Hole Direction  Final Status Current Status            Basin  \
# 0           NaN     HORIZONTAL  OIL PRODUCER              A  WILLISTON BASIN
# 1           NaN     HORIZONTAL  OIL PRODUCER              A  WILLISTON BASIN
# 2           NaN     HORIZONTAL  OIL PRODUCER              A  WILLISTON BASIN
# 3           NaN     HORIZONTAL  OIL PRODUCER              A  WILLISTON BASIN
# 4           NaN     HORIZONTAL  OIL PRODUCER              A  WILLISTON BASIN
#
#            ...           Depth Top_y Depth Base  PRODFit Top Formation  \
# 0          ...               10928.0    19682.0                    NaN
# 1          ...               10928.0    19682.0                    NaN
# 2          ...               10928.0    19682.0                    NaN
# 3          ...               10928.0    19682.0                    NaN
# 4          ...               10928.0    19682.0                    NaN
#
#   PRODFit Base Formation Pressure Flowing Tubing Pressure Flowing Casing  \
# 0                    NaN                     NaN                  2600.0
# 1                    NaN                     NaN                  2600.0
# 2                    NaN                     NaN                  2600.0
# 3                    NaN                     NaN                  2600.0
# 4                    NaN                     NaN                  2600.0
#
#    Pressure Shutin Tubing  Pressure Shutin Casing  Bottom Hole Run Depth  \
# 0                     NaN                     NaN                    NaN
# 1                     NaN                     NaN                    NaN
# 2                     NaN                     NaN                    NaN
# 3                     NaN                     NaN                    NaN
# 4                     NaN                     NaN                    NaN
#
#    Pressure Bottom Hole
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 111 columns]

# %%
i = df.parse("Completion")
g = g.merge(i, left_on="UWI", right_on="UWI", how="outer")

# %%
list(g)
# Out:
# ['UWI',
#  'Operator Name',
#  'Current Operator Name',
#  'Lease Name',
#  'Well Num',
#  'OS Indicator',
#  'Hole Direction',
#  'Final Status',
#  'Current Status',
#  'Basin',
#  'Basin Code',
#  'Sub Basin',
#  'Sub Basin Code',
#  'Play Name',
#  'Play Type',
#  'Permit Date',
#  'Depth Total Driller',
#  'Depth Total Logger',
#  'Depth True Vertical',
#  'Depth Whipstock',
#  'Class Initial Name',
#  'Class Initial Code',
#  'Class Final Name',
#  'Class Final Code',
#  'Status Final Code',
#  'Formation Projected Name',
#  'Depth Total Projected',
#  'Formation at TD Name',
#  'PRODFit Formation at TD Name',
#  'Formation Producing Name',
#  'PRODFit Top Formation Producing Name',
#  'PRODFit Base Formation Producing Name',
#  'Elevation Reference Value',
#  'Elevation Reference Datum',
#  'Ground Elevation',
#  'Date First Spud',
#  'Date Spud',
#  'Date Completion',
#  'Date Rig Release',
#  'Date First Report',
#  'Date Last Activity',
#  'Depth Water Value',
#  'Depth Water Datum',
#  'Surface Latitude',
#  'Surface Longitude',
#  'Surface LL Source',
#  'BH Latitude',
#  'BH Longitude',
#  'BH LL Source',
#  'Activity Code',
#  'Source_y',
#  'Num Frac Stages',
#  'Stages Avail',
#  'Num Treatment Records',
#  'Proppant - Sand (lbs)',
#  'Proppant - Resin Coated Sand (lbs)',
#  'Proppant - Ceramic (lbs)',
#  'Proppant - Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Ceramic (lbs)',
#  'Proppant - Sand, Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Ceramic, Resin Coated Sand (lbs)',
#  'Proppant - Sand, Ceramic, Resin Coated Ceramic (lbs)',
#  'Proppant - Sand, Resin Coated Sand, Ceramic, Resin Coated Ceramic (lbs)',
#  'Proppant - Bauxite (lbs)',
#  'Proppant - Walnut (lbs)',
#  'Proppant - Marble (lbs)',
#  'Proppant - Gravel (lbs)',
#  'Proppant - Sand, Bauxite Ceramic (lbs)',
#  'Proppant - Other (lbs)',
#  'Total Proppant (lbs)',
#  'Fluid/Water (Gals)',
#  'Fluid - Slick Water (Gals)',
#  'Fluid - Salt Water (Gals)',
#  'Fluid - Foam (Gals)',
#  'Fluid - Oil (Gals)',
#  'Fluid - Potassium Chloride (Gals)',
#  'Fluid - Surfactant (Gals)',
#  'Fluid - Emulsion (Gals)',
#  'N2/CO2 Gas (Gals)',
#  'Acid (Gals)',
#  'Gel/x-link (Gals)',
#  'Fluid - Explosive (Gals)',
#  'Fluid - Other (Gals)',
#  'Total Fluid (gals)',
#  'Total Proppant (lbs.) / Total Fluid (gal)',
#  'Top Source',
#  'Interpreter',
#  'Code',
#  'Name',
#  'Depth Top_x',
#  'Depth Top UOM_x',
#  'Base Depth',
#  'Base Depth UOM',
#  'Source_x',
#  'Test Type',
#  'Pressure Obs Number',
#  'Fluid Type',
#  'BH Pressure Obs Number',
#  'Date',
#  'Formation Top Name_x',
#  'Formation Base Name_x',
#  'Depth Top_y',
#  'Depth Base_x',
#  'PRODFit Top Formation',
#  'PRODFit Base Formation',
#  'Pressure Flowing Tubing',
#  'Pressure Flowing Casing',
#  'Pressure Shutin Tubing',
#  'Pressure Shutin Casing',
#  'Bottom Hole Run Depth',
#  'Pressure Bottom Hole',
#  'Source_y',
#  'Number',
#  'Completion Date',
#  'Formation Top Name_y',
#  'Formation Base Name_y',
#  'Depth Top',
#  'Depth Top UOM_y',
#  'Depth Base_y',
#  'Depth Base UOM',
#  'PRODFit Formation Top Name',
#  'PRODFit Formation Base Name',
#  'Type',
#  'Method',
#  'Remark']

# %%
e = [
    "UWI",
    "Operator Name",
    "Current Operator Name",
    "Lease Name",
    "Well Num",
    "OS Indicator",
    "Hole Direction",
    "Final Status",
    "Current Status",
    "Basin",
    "Basin Code",
    "Sub Basin",
    "Sub Basin Code",
    "Play Name",
    "Play Type",
    "Permit Date",
    "Depth Total Driller",
    "Depth Total Logger",
    "Depth True Vertical",
    "Depth Whipstock",
    "Class Initial Name",
    "Class Initial Code",
    "Class Final Name",
    "Class Final Code",
    "Status Final Code",
    "Formation Projected Name",
    "Depth Total Projected",
    "Formation at TD Name",
    "PRODFit Formation at TD Name",
    "Formation Producing Name",
    "PRODFit Top Formation Producing Name",
    "PRODFit Base Formation Producing Name",
    "Elevation Reference Value",
    "Elevation Reference Datum",
    "Ground Elevation",
    "Date First Spud",
    "Date Spud",
    "Date Completion",
    "Date Rig Release",
    "Date First Report",
    "Date Last Activity",
    "Depth Water Value",
    "Depth Water Datum",
    "Surface Latitude",
    "Surface Longitude",
    "Surface LL Source",
    "BH Latitude",
    "BH Longitude",
    "BH LL Source",
    "Activity Code",
    "Source_y",
    "Num Frac Stages",
    "Stages Avail",
    "Num Treatment Records",
    "Proppant - Sand (lbs)",
    "Proppant - Resin Coated Sand (lbs)",
    "Proppant - Ceramic (lbs)",
    "Proppant - Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Ceramic (lbs)",
    "Proppant - Sand, Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Ceramic, Resin Coated Sand (lbs)",
    "Proppant - Sand, Ceramic, Resin Coated Ceramic (lbs)",
    "Proppant - Sand, Resin Coated Sand, Ceramic, Resin Coated Ceramic (lbs)",
    "Proppant - Bauxite (lbs)",
    "Proppant - Walnut (lbs)",
    "Proppant - Marble (lbs)",
    "Proppant - Gravel (lbs)",
    "Proppant - Sand, Bauxite Ceramic (lbs)",
    "Proppant - Other (lbs)",
    "Total Proppant (lbs)",
    "Fluid/Water (Gals)",
    "Fluid - Slick Water (Gals)",
    "Fluid - Salt Water (Gals)",
    "Fluid - Foam (Gals)",
    "Fluid - Oil (Gals)",
    "Fluid - Potassium Chloride (Gals)",
    "Fluid - Surfactant (Gals)",
    "Fluid - Emulsion (Gals)",
    "N2/CO2 Gas (Gals)",
    "Acid (Gals)",
    "Gel/x-link (Gals)",
    "Fluid - Explosive (Gals)",
    "Fluid - Other (Gals)",
    "Total Fluid (gals)",
    "Total Proppant (lbs.) / Total Fluid (gal)",
    "Top Source",
    "Interpreter",
    "Code",
    "Name",
    "Depth Top_x",
    "Depth Top UOM_x",
    "Base Depth",
    "Base Depth UOM",
    "Source_x",
    "Test Type",
    "Pressure Obs Number",
    "Fluid Type",
    "BH Pressure Obs Number",
    "Date",
    "Formation Top Name_x",
    "Formation Base Name_x",
    "Depth Top_y",
    "Depth Base_x",
    "PRODFit Top Formation",
    "PRODFit Base Formation",
    "Pressure Flowing Tubing",
    "Pressure Flowing Casing",
    "Pressure Shutin Tubing",
    "Pressure Shutin Casing",
    "Bottom Hole Run Depth",
    "Pressure Bottom Hole",
    "Source_y",
    "Number",
    "Formation Top Name_y",
    "Formation Base Name_y",
    "Depth Top",
    "Depth Top UOM_y",
    "Depth Base_y",
    "Depth Base UOM",
    "Type",
    "Method",
]

# %%
g = g[e]

# %%
g.describe()
# Out:
#                 UWI  OS Indicator  Basin Code  Sub Basin Code  \
# count  1.074280e+05           0.0    107428.0    1.074280e+05
# mean   3.305201e+13           NaN    713200.0    1.000000e+11
# std    5.195915e+09           NaN         0.0    9.780976e-01
# min    3.302503e+13           NaN    713200.0    1.000000e+11
# 25%    3.305302e+13           NaN    713200.0    1.000000e+11
# 50%    3.305304e+13           NaN    713200.0    1.000000e+11
# 75%    3.305306e+13           NaN    713200.0    1.000000e+11
# max    3.305308e+13           NaN    713200.0    1.000000e+11
#
#        Depth Total Driller  Depth Total Logger  Depth True Vertical  \
# count        107428.000000        23477.000000         83843.000000
# mean          18381.403489        12476.152447         10877.239170
# std            3941.081985         2221.305638           279.969943
# min            9050.000000         9057.000000          9668.000000
# 25%           14340.000000        11020.000000         10696.000000
# 50%           20627.000000        11020.000000         10903.000000
# 75%           21055.000000        14340.000000         11096.000000
# max           27242.000000        25213.000000         11557.000000
#
#        Depth Whipstock  Depth Total Projected  PRODFit Formation at TD Name  \
# count       322.000000          103031.000000                           0.0
# mean       9519.950311           18656.436218                           NaN
# std        1429.980257            3881.152539                           NaN
# min        7400.000000            9050.000000                           NaN
# 25%        7404.000000           15167.000000                           NaN
# 50%       10060.000000           20721.000000                           NaN
# 75%       10337.000000           21121.000000                           NaN
# max       18339.000000           28497.000000                           NaN
#
#            ...        PRODFit Base Formation  Pressure Flowing Tubing  \
# count      ...                           0.0             24681.000000
# mean       ...                           NaN              1391.115433
# std        ...                           NaN               885.791773
# min        ...                           NaN                 0.000000
# 25%        ...                           NaN               600.000000
# 50%        ...                           NaN              1275.000000
# 75%        ...                           NaN              2082.000000
# max        ...                           NaN              4000.000000
#
#        Pressure Flowing Casing  Pressure Shutin Tubing  \
# count             59209.000000              929.000000
# mean               1641.936378             2070.263724
# std                 902.972699              373.995293
# min                   0.000000              700.000000
# 25%                 950.000000             2175.000000
# 50%                1579.000000             2175.000000
# 75%                2300.000000             2175.000000
# max                4700.000000             2175.000000
#
#        Pressure Shutin Casing  Bottom Hole Run Depth  Pressure Bottom Hole  \
# count              207.000000                    0.0                   0.0
# mean               813.768116                    NaN                   NaN
# std               1054.464620                    NaN                   NaN
# min                 20.000000                    NaN                   NaN
# 25%                100.000000                    NaN                   NaN
# 50%                200.000000                    NaN                   NaN
# 75%               1800.000000                    NaN                   NaN
# max               3450.000000                    NaN                   NaN
#
#               Number      Depth Top   Depth Base_y
# count  107397.000000  106901.000000  106901.000000
# mean        5.373707   11243.250961   18140.055659
# std        11.189311     813.153708    4267.080199
# min         1.000000    4760.000000    4982.000000
# 25%         1.000000   10853.000000   14222.000000
# 50%         1.000000   11185.000000   20586.000000
# 75%         2.000000   11444.000000   21034.000000
# max        57.000000   22969.000000   27242.000000
#
# [8 rows x 72 columns]

# %%
g.UWI.value_counts()
# Out:
# 33053005070000    13680
# 33053020800000     7749
# 33053020970000      312
# 33053014590000      252
# 33053022110000      240
# 33053011650000      195
# 33053012560000      168
# 33053018890000      165
# 33033002140000      144
# 33053074220000      140
# 33053017620000      140
# 33053074230000      136
# 33053073160000      136
# 33053073130000      136
# 33053070720000      132
# 33053070690000      132
# 33053073100000      128
# 33053019790000      128
# 33053074520000      128
# 33053065400000      126
# 33053070700000      124
# 33053070740000      124
# 33053034480000      120
# 33053049570000      120
# 33053060100000      120
# 33053048620000      116
# 33053067280000      110
# 33053024350000      108
# 33053035860000      108
# 33053068790000      108
#                   ...
# 33053048030100        1
# 33053024810100        1
# 33053036170300        1
# 33053036080200        1
# 33053036320100        1
# 33053041930100        1
# 33053047850100        1
# 33053068070100        1
# 33053030670100        1
# 33053077030300        1
# 33053046900100        1
# 33053049360100        1
# 33053069160100        1
# 33053060640100        1
# 33025030210100        1
# 33053046150200        1
# 33053015270000        1
# 33053040120100        1
# 33053077630100        1
# 33053038940100        1
# 33053055140100        1
# 33053038310100        1
# 33053061910100        1
# 33053061510100        1
# 33053049140300        1
# 33053074330200        1
# 33053050500100        1
# 33053050220100        1
# 33053052990100        1
# 33053043870100        1
# Name: UWI, dtype: int64
